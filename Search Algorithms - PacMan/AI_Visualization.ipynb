# %%
import pandas as pd
import io
import numpy as np
from io import StringIO
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight') 
plt.rcParams["figure.figsize"] = [10, 6]

# %%
plotdata = pd.DataFrame({
    "BFS":[15,92,269,620],
    "DFS":[15,59,146,390],
    "UCS":[15,92,269,620],
    "A*":[15,92,269,620],
    "BIS":[12,54,185,606]
    }, 
    index=["Tiny", "Small", "Medium", "Big"]
)
plotdata.plot(kind="barh",)
plt.title("Number of Nodes expanded by search algorithms")
plt.xlabel("Maze Size")
plt.ylabel("Number of Nodes expanded")
# Out:
# Text(0, 0.5, 'Number of Nodes expanded')

# %%
plotdata = pd.DataFrame({
    "BFS":[8,19,68,210],
    "DFS":[10,49,130,210],
    "UCS":[8,19,68,210],
    "A*":[8,19,68,210],
    "BIS":[8,19,68,210]
    }, 
    index=["Tiny", "Small", "Medium", "Big"]
)
plotdata.plot(kind="barh",)
plt.title("Cost of search algorithms")
plt.xlabel("Maze Size")
plt.ylabel("Cost")
# Out:
# Text(0, 0.5, 'Cost')

# %%
plotdata = pd.DataFrame({
    "Manhattan":[14,53,221,549],
    "Cosine":[15,91,268,619],
    "Chebyshev":[13,56,228,578],
    "Euclidean":[13,56,226,557],
    "Canberra":[15,92,269,620],
    }, 
    index=["Tiny", "Small", "Medium", "Big"]
)
plotdata.plot(kind="barh",)
plt.title("Performance of A* algorithm with different heuristic measures")
plt.xlabel("Maze Size")
plt.ylabel("Number of Nodes expanded")
# Out:
# Text(0, 0.5, 'Number of Nodes expanded')

# %%
plotdata = pd.DataFrame({
    "Manhattan":[8,19,68,210],
    "Cosine":[8,19,68,210],
    "Chebyshev":[8,19,68,210],
    "Euclidean":[8,19,68,210],
    "Canberra":[8,19,68,210],

    }, 
    index=["Tiny", "Small", "Medium", "Big"]
)
plotdata.plot(kind="barh",)
plt.title("Performance of MMe algorithm with different heuristic measures")
plt.xlabel("Maze Size")
plt.ylabel("Cost")
# Out:
# Text(0, 0.5, 'Cost')

# %%
plotdata = pd.DataFrame({
    "Manhattan":[12,39,184,549],
    "Cosine":[12,50,185,606],
    "Chebyshev":[12,45,185,606],
    "Euclidean":[12,45,185,606],
    "Canberra":[15,50,185,606],
    "Hamming":[12,49,185,606]
    }, 
    index=["Tiny", "Small", "Medium", "Big"]
)
plotdata.plot(kind="barh",)
plt.title("Performance of MMe algorithm with different heuristic measures")
plt.xlabel("Maze Size")
plt.ylabel("Number of Nodes expanded")
# Out:
# Text(0, 0.5, 'Number of Nodes expanded')

# %%
plotdata = pd.DataFrame({
    "Manhattan":[8,19,68,210],
    "Cosine":[8,19,68,210],
    "Chebyshev":[8,19,68,210],
    "Euclidean":[8,19,68,210],
    "Canberra":[8,19,68,210],
    "Hamming":[8,19,68,210]
    }, 
    index=["Tiny", "Small", "Medium", "Big"]
)
plotdata.plot(kind="barh",)
plt.title("Performance of MMf algorithm with different heuristic measures")
plt.xlabel("Maze Size")
plt.ylabel("Cost")
# Out:
# Text(0, 0.5, 'Cost')

# %%
plotdata = pd.DataFrame({
    "Manhattan":[14,52,213,586],
    "Cosine":[15,85,229,586],
    "Chebyshev":[12,55,217,586],
    "Euclidean":[12,55,217,586],
    "Canberra":[15,85,229,586],
    "Hamming":[14,81,229,586]
    }, 
    index=["Tiny", "Small", "Medium", "Big"]
)
plotdata.plot(kind="barh")
plt.title("Performance of MMf algorithm with different heuristic measures")
plt.xlabel("Maze Size")
plt.ylabel("Number of Nodes expanded")
# Out:
# Text(0, 0.5, 'Number of Nodes expanded')
